# %% [markdown]
# Data Types
#
# Tells python what kind of data a value is so it knows how to store it and what operations are allowed on it
# Eg

# %%
x = 10

# %% [markdown]
# now ive just told phyton 10 is a number, so it allows math
