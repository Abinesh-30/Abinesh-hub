# %% [markdown]
# Machine learning: is where the computer learns patterns from a data
# ML algorithms build mathematical models from historical or observed data
#
#
# supervised vs unsupervised Ml
#
# supervised machine learning - learns from examples where the outcome is already known
# unsupervised machine learning works with data where no outcomes are given in advance
#
#
#
# Features + labels     What are they?
# features- are inputs you give a model (information it uses to make a prediction)
# lablels - are the correct answers you want a model to learn to predict
