# %% [markdown]
# python:
#  introduction
#
#  It's a prgraming language used web development (server-side), software development, mathematics, system scripting.
#
#  why pyhton:
#  1. It's got simple synatx similar to the english language

# %%
print(" Hello, world")
# Out:
#  Hello, world

# %% [markdown]
# Below is an example of python indentation, showing indentation in python is important as python uses that to indicate a block of code.
#
# NOTE: Indentation (space at the beginning of the code) is VERY IMPORTANT

# %%
if 5 > 2:
    print("Five is greater than two!")
# Out:
# Five is greater than two!

# %% [markdown]
# Python variables
#
# variables are created to assign a value to it
# eg:

# %%
x = 5 # ive just told python that x = 5 
y = "Hello world" # Here ive told that y = hello world

## pyhton has no command for declaring a variable

# %% [markdown]
# Python statements: are instruction

# %%
# example of statements (basically instructions)

print(" hello world")   # is considered as the 1st statement
print("Have a good day")    
print("python is alright")

# %%
# semi colons allow statements to be written in the same line

# %%
print("hello world"); print("Have a good day"); print("python is alright") 
# ';' can be used to have statements in the same line of code
# Out:
# hello world
# Have a good day
# python is alright

# %% [markdown]
# end= "(add a space)" is used to print multiple words on the same line

# %%
print("hello world", end=" ")
print("I will print on the same line")
# Out:
# hello world I will print on the same line

# %%
###printing number


# we can use the print function to display numbers
# ONLY RULE IS: we dont need to use quotes

print(30) # no quotes

# we can use the print function to do maths

print(2 + 2)

## Mix text and numbers

print("I am", 22, "years old")
# Out:
# 30
# 4
# I am 22 years old

# %%
## python variables 
x = 22 
x = "abinesh"
#these are strings
# string is text - can be letters, words symbols or numbers written in quotes
x = "teenu"

print(x) # the reason why its not printing everyhting like 22.. etc is becuase
#pyhton eads top to bottom, reassigning x to the new value each time

#casting: when you want to specify what data type the variable is
#eg 

x = str(22)
y = int(23)
z= float(2.3) # a float is number with a decimal point

print(type(x))
# Out:
# teenu
# <class 'str'>

# %%
# RULE with variables names 
# A variable name must start with a letter or the underscore character
