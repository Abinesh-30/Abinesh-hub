# %% [markdown]
# code readability
# we use the # to comment
# - has to be short and informative
# - when submitting never leave out lines
#
# ---
# triple dash to create a multiline quote
# ---
#
# linter: used to put your code in to check if its in standard

# %% [markdown]
# while loop
#
# will run until the conditions are met.

# %%
count = 1  # Initialize a variable

while count <= 5:  # Loop runs while count is less than or equal to 5
    print(f"Count is: {count}")  # Print the current count
    count += 1  # Increase count by 1 in each iteration; can also be written count = count + 1

print("Loop finished!")  # This prints after the loop ends

# Note: two print statements have different 'execution context'
# Out:
# Count is: 1
# Count is: 2
# Count is: 3
# Count is: 4
# Count is: 5
# Loop finished!

# %% [markdown]
# simpliest while loop

# %%
while True: # It will repeat it lots of time becasue its true runnning forever
    print('I am always right')

# %% [markdown]
# 4 compund data type
# list – ordered, mutable sequence
# tuple – ordered, immutable sequence
# set – unordered collection of unique elements
# dict – key–value pairs (dictionary, mapping type)

# %%
my_list = [1, 2, 3]
my_tuple = (1, 2, 3)
my_set = {1, 2, 3}
my_dict = {'a': 1, 'b': 2, 'c': 3}

# %% [markdown]
# for loop: performs operation on each part

# %%
fruits = ["apple", "banana", "cherry"] # my list 

for fruit in fruits:
    print(f"I like {fruit}!")
# Out:
# I like apple!
# I like banana!
# I like cherry!

# %%
# Loop for 'o' patterns: square
# Use nested for loops
n = 5
for i in range(n): # this is an alder loop
    for j in range(n):
        print('o', end='  ')
    print()
# Out:
# o  o  o  o  o
# o  o  o  o  o
# o  o  o  o  o
# o  o  o  o  o
# o  o  o  o  o

# %%
# Loop for 'o' patterns: square
# Use nested for loops
n = 5
for i in range(n):
    for j in range(i + 1):  # + 1 
        print('o', end='  ')
    print()
# Out:
# o
# o  o
# o  o  o
# o  o  o  o
# o  o  o  o  o
